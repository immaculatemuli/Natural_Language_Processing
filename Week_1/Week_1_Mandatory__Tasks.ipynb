# %% [markdown]
# <a href="https://colab.research.google.com/github/immaculatemuli/Natural_Language_Processing/blob/main/Week_1/Week_1_Mandatory__Tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# WEEK 1: INTRODUCTION TO NLP AND APPLICATIONS
#
# 1.Python installation
#
# 2.NLTK installation
#
# 3.Tokenization Output
#
# 4.Stopwords Removal Output

# %%
#
# DATASET: CBK Annual Report & Financial Statements 2024/25
#
# Step 1: Download the PDF from the official CBK website:
#         https://www.centralbank.go.ke/reports/
#         File name: 1084981846_2025 Annual Report.pdf
#
# Step 2: Upload the PDF to Google Colab using one of these methods:
#
#           Upload directly each session:
#         from google.colab import files
#         files.upload()    ← click and select the PDF
#
#
# Step 3: Update the pdf_path variable below to match your file location

# %%
# !pip install PyPDF2

import PyPDF2

pdf_path = '/content/1084981846_2025 Annual Report.pdf'

with open(pdf_path, 'rb') as f:
    reader = PyPDF2.PdfReader(f)
    print(f'Total pages: {len(reader.pages)}')

    # Extract text from pages 7 to 40 (the main report content)
    text = ''
    for page_num in range(7, 40):
        page_text = reader.pages[page_num].extract_text()
        if page_text:
            text += page_text + ' '

print(f'Extracted {len(text):,} characters')
print(f'Preview: {text[:300]}')
# Out:
# ...
# Total pages: 152
# Extracted 70,923 characters
# Preview: VICENTRAL BANK OF KENYA
# ANNUAL REPORT & FINANCIAL STATEMENTS 2024/25
# To be a World Class Modern Central BankABBREVIATIONS AND ACRONYMS
# AACB  Association of African Central Banks
# ACH Automated Clearing House
# AfCFTA  African Continental Free Trade Area
# AMCP  African Monetary Cooperation Programme
# A

# %%
# !python --version

# %%
# ── 3: NLTK Installation

# !pip install nltk --quiet
# !pip install PyPDF2 --quiet

import nltk
nltk.download('punkt')           # for tokenization
nltk.download('punkt_tab')       # updated tokenizer data
nltk.download('stopwords')       # for stop word removal
nltk.download('wordnet')         # for lemmatization
nltk.download('averaged_perceptron_tagger')  # for POS tagging

print('=' * 50)
print('All NLP tools installed and ready!')
print('We will analyze the CBK Annual Report 2024/25')
print('=' * 50)
# Out:
# ...
# All NLP tools installed and ready!
# We will analyze the CBK Annual Report 2024/25
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# 4 — Tokenization Output using CBK Annual Report 2024/25

import PyPDF2
from nltk.tokenize import word_tokenize, sent_tokenize

#  Step 1: Load CBK Annual Report from Google Drive
pdf_path = '/content/1084981846_2025 Annual Report.pdf'

cbk_text = ''
with open(pdf_path, 'rb') as f:
    reader = PyPDF2.PdfReader(f)
    print(f"Total pages in CBK Annual Report: {len(reader.pages)}")

    # Extract pages 7 to 15 (Governor Foreword + Domestic Economy)
    for page_num in range(7, 15):
        page_text = reader.pages[page_num].extract_text()
        if page_text:
            cbk_text += page_text + ' '

print(f"Text extracted: {len(cbk_text):,} characters\n")

#  Step 2: Sentence Tokenization
sentences = sent_tokenize(cbk_text)
print("=" * 55)
print("  4 — TOKENIZATION OUTPUT")
print("  Dataset: CBK Annual Report & Financial Statements 2024/25")
print("=" * 55)

print(f"\nSENTENCE TOKENIZATION:")
print(f"Total sentences found: {len(sentences)}")
print("\nFirst 5 sentences from the CBK Report:")
for i, sent in enumerate(sentences[:5], 1):
    print(f"\n  Sentence {i}:")
    print(f"  {sent.strip()[:120]}...")

#  Step 3: Word Tokenization
word_tokens = word_tokenize(cbk_text)
print(f"\n{'='*55}")
print(f"WORD TOKENIZATION:")
print(f"Total word tokens : {len(word_tokens):,}")
print(f"First 20 tokens   : {word_tokens[:20]}")
print(f"{'='*55}")
print("Tokenization complete. Text is now ready for preprocessing.")
# Out:
# Total pages in CBK Annual Report: 152
# Text extracted: 10,266 characters
#
# ...
#   4 — TOKENIZATION OUTPUT
#   Dataset: CBK Annual Report & Financial Statements 2024/25
# ...
#
# SENTENCE TOKENIZATION:
# Total sentences found: 42
#
# First 5 sentences from the CBK Report:
#
#   Sentence 1:
#   VICENTRAL BANK OF KENYA
# ANNUAL REPORT & FINANCIAL STATEMENTS 2024/25
# To be a World Class Modern Central BankABBREVIATION...
#
#   Sentence 2:
#   The Bank also rolled out its Strategic Plan for 2024-2027....
#
#   Sentence 3:
#   The financial year was also characterised by elevated global uncertainties, largely attributed to
# implementation of hig...
#
#   Sentence 4:
#   Nevertheless, global inflation eased during the period, with central banks in major economies
# lowering their interest r...
#
#   Sentence 5:
#   The Kenyan economy remained resilient during
# the period, supported by robust performance of key service sectors and agr...
#
# ...
# WORD TOKENIZATION:
# Total word tokens : 1,640
# ...

# %%
# This fixes ALL your notebooks at once
# !pip install nbformat -q

import nbformat
import os
from google.colab import files

# Upload all your broken notebooks
uploaded = files.upload()  # select ALL .ipynb files at once

# Fix each one
for filename in uploaded.keys():
    print(f"Fixing {filename}...")

    # Read the notebook
    with open(filename, 'r', encoding='utf-8') as f:
        nb = nbformat.read(f, as_version=4)

    # Clear all outputs (this is what fixes the GitHub error)
    for cell in nb.cells:
        if cell.cell_type == 'code':
            cell.outputs = []
            cell.execution_count = None

    # Save fixed version
    fixed_name = 'FIXED_' + filename
    with open(fixed_name, 'w', encoding='utf-8') as f:
        nbformat.write(nb, f)

    print(f"Done — {fixed_name} is ready")

# Download all fixed files
import glob
for f in glob.glob('/content/FIXED_*.ipynb'):
    files.download(f)
    print(f"Downloaded: {f}")

print("\nAll done! Upload these FIXED files to GitHub")
# Out:
#      <input type="file" id="files-9479f9dc-9c8e-4fd6-922b-eb6fa177f0fe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9479f9dc-9c8e-4fd6-922b-eb6fa177f0fe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# 5 — Stopwords Removal Output using CBK Annual Report 2024/25

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

#  Load stopwords
stop_words = set(stopwords.words('english'))

#  Tokenize and filter
all_tokens = word_tokenize(cbk_text.lower())

# Keep only alphabetic words not in stopwords list
filtered_tokens = [
    word for word in all_tokens
    if word.isalpha() and word not in stop_words
]

#  Results
print("=" * 55)
print("  5 — STOPWORDS REMOVAL OUTPUT")
print("  Dataset: CBK Annual Report & Financial Statements 2024/25")
print("=" * 55)

print(f"\nBEFORE removal : {len(all_tokens):,} tokens")
print(f"AFTER removal  : {len(filtered_tokens):,} tokens")
print(f"Removed        : {len(all_tokens) - len(filtered_tokens):,} stopwords")
print(f"Reduction      : {((len(all_tokens)-len(filtered_tokens))/len(all_tokens)*100):.1f}%")

print(f"\nSample of REMOVED stopwords (common words with no meaning):")
removed = [w for w in all_tokens if w in stop_words]
print(f"  {list(set(removed))[:15]}")

print(f"\nMeaningful words REMAINING (first 25):")
print(f"  {filtered_tokens[:25]}")

print(f"\nTop 10 most frequent meaningful words in the CBK Report:")
from collections import Counter
freq = Counter(filtered_tokens)
for word, count in freq.most_common(10):
    bar = '█' * count
    print(f"  {word:<20} {count:>3}  {bar}")

print(f"\n{'='*55}")
print("Stopwords removed. Clean tokens ready for NLP analysis.")
# Out:
# ...
#   5 — STOPWORDS REMOVAL OUTPUT
#   Dataset: CBK Annual Report & Financial Statements 2024/25
# ...
#
# BEFORE removal : 1,630 tokens
# AFTER removal  : 966 tokens
# Removed        : 664 stopwords
# Reduction      : 40.7%
#
# Sample of REMOVED stopwords (common words with no meaning):
#   ['these', 'out', 'by', 'are', 'was', 'i', 'during', 'all', 'its', 'to', 'other', 'were', 'has', 'more', 'the']
#
# Meaningful words REMAINING (first 25):
#   ['vicentral', 'bank', 'kenya', 'annual', 'report', 'financial', 'statements', 'world', 'class', 'modern', 'central', 'bankabbreviations', 'acronyms', 'aacb', 'association', 'african', 'central', 'banks', 'ach', 'automated', 'clearing', 'house', 'afcfta', 'african', 'continental']
#
# Top 10 most frequent meaningful words in the CBK Report:
#   bank                  26  ██████████████████████████
#   financial             19  ███████████████████
#   kenya                 17  █████████████████
#   central               16  ████████████████
# ...
